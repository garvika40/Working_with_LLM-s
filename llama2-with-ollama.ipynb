# %% [markdown]
# #Terminal commands to run ollama

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !curl -fsSL https://ollama.com/install.sh|sh

import pandas as pd
# Out:
# >>> Downloading ollama...
# ######################################################################## 100.0%#=#=#
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
import subprocess

# Start ollama serve in the background
proc = subprocess.Popen(['ollama', 'serve'])

# You can now run other commands, check if the process is up, etc.
# Use proc.poll() to check if the process is still running
# Use proc.terminate() to stop it if needed

# %%
proc.poll()

# %%
# !ollama pull llama2
# Out:
# Couldn't find '/root/.ollama/id_ed25519'. Generating new private key.
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAICps5KlN9qqQQrbZzX9mJXc5GPBd0LlJZpKnKsfHZlra
# time=2024-03-28T11:57:52.729Z level=INFO source=images.go:806 msg="total blobs: 0"
# time=2024-03-28T11:57:52.730Z level=INFO source=images.go:813 msg="total unused blobs removed: 0"
# time=2024-03-28T11:57:52.730Z level=INFO source=routes.go:1110 msg="Listening on 127.0.0.1:11434 (version 0.1.29)"
# time=2024-03-28T11:57:52.730Z level=INFO source=payload_common.go:112 msg="Extracting dynamic libraries to /tmp/ollama676805227/runners ..."
# [GIN] 2024/03/28 - 11:57:57 | 200 |      51.898µs |       127.0.0.1 | HEAD     "/"
# pulling manifest ⠋
# time=2024-03-28T11:57:57.302Z level=INFO source=payload_common.go:139 msg="Dynamic LLM libraries [rocm_v60000 cpu_avx2 cpu cuda_v11 cpu_avx]"
# time=2024-03-28T11:57:57.302Z level=INFO source=gpu.go:77 msg="Detecting GPU type"
# ...

# %%
# !sudo lsof -i :11434
# Out:
# sudo: lsof: command not found

# %%
# !sudo kill 3206

# %%
# !ollama create myntra_classification -f /content/drive/MyDrive/llama2/model_file
# Out:
# [GIN] 2024/03/28 - 11:58:36 | 200 |      44.904µs |       127.0.0.1 | HEAD     "/"
#
# Error: open /content/drive/MyDrive/llama2/model_file: no such file or directory

# %%
# !ollama list
# Out:
# [GIN] 2024/03/28 - 11:58:37 | 200 |      33.184µs |       127.0.0.1 | HEAD     "/"
# [GIN] 2024/03/28 - 11:58:37 | 200 |     743.092µs |       127.0.0.1 | GET      "/api/tags"
# NAME         	ID          	SIZE  	MODIFIED
# llama2:latest	78e26419b446	3.8 GB	3 seconds ago

# %%
#!ollama run llama2

# %% [markdown]
# #OLLAMA Using Langchain

# %%
# !pip install langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 696.5 kB/s eta 0:00:00:--:--
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.2 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.0/273.0 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.9.10
#     Uninstalling orjson-3.9.10:
#       Successfully uninstalled orjson-3.9.10
# ...

# %%
from langchain_community.llms import Ollama

# %%
import subprocess, time

p = subprocess.Popen(["sh", "-c", "sleep 1; echo never; sleep 3"], stdout=subprocess.PIPE)

# Wait for the subprocess to complete
output, _ = p.communicate()

# Print the subprocess output
print(output.decode())

print("one")
time.sleep(2)  # Or adjust the sleep time as needed
print("two")
print(p.poll())  # This should print None if p.communicate() waits for the process
# Out:
# never
#
# one
# two
# 0

# %%
llm=Ollama(model="llama2")

# %%
llm.invoke("Hii")
# Out:
# time=2024-03-28T11:59:05.894Z level=INFO source=cpu_common.go:11 msg="CPU has AVX2"
# time=2024-03-28T11:59:05.894Z level=INFO source=gpu.go:119 msg="CUDA Compute Capability detected: 7.5"
# time=2024-03-28T11:59:05.894Z level=INFO source=cpu_common.go:11 msg="CPU has AVX2"
# time=2024-03-28T11:59:05.894Z level=INFO source=gpu.go:119 msg="CUDA Compute Capability detected: 7.5"
# time=2024-03-28T11:59:05.894Z level=INFO source=cpu_common.go:11 msg="CPU has AVX2"
# time=2024-03-28T11:59:05.904Z level=INFO source=dyn_ext_server.go:90 msg="Loading Dynamic llm server: /tmp/ollama676805227/runners/cuda_v11/libext_server.so"
# time=2024-03-28T11:59:05.904Z level=INFO source=dyn_ext_server.go:150 msg="Initializing llama server"
# ggml_init_cublas: GGML_CUDA_FORCE_MMQ:   yes
# ggml_init_cublas: CUDA_USE_TENSOR_CORES: no
# ggml_init_cublas: found 2 CUDA devices:
#   Device 0: Tesla T4, compute capability 7.5, VMM: yes
#   Device 1: Tesla T4, compute capability 7.5, VMM: yes
# ...

# %% [markdown]
# #Read the Myntra_data

# %%
import pandas as pd

# %%
import pandas as pd
import csv
df = pd.read_csv("/kaggle/input/myntra/myntra_excel.csv", usecols=[2,9])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 4
#       2 import csv
# ...

# %%
myntra  = df.drop_duplicates(subset=['title'])
# After removing duplicate values, we reset index
myntra.reset_index(drop=True, inplace = True)
myntra = myntra.drop_duplicates(subset = ["product_id"])
myntra.reset_index(inplace = True)
# Product_id == index
myntra['product_id'] = myntra['index']

# %%
ratings = pd.read_csv('/kaggle/input/myntra/ratings.csv')
ratings.drop('Unnamed: 0' , axis =1 , inplace = True)
merged_data = ratings.merge(myntra , on="product_id")
merged_data.head(5)
# Out:
#    userId  product_id  Rating  index                        title
# 0    3269           0    4.30      0  IMARA Women Black Solid Top
# 1    4575           0    3.95      0  IMARA Women Black Solid Top
# 2    3844           0    3.72      0  IMARA Women Black Solid Top
# 3    1260           0    3.98      0  IMARA Women Black Solid Top
# 4    5298           0    4.37      0  IMARA Women Black Solid Top

# %%
unique_products = list(merged_data['title'].unique())
unique_products=unique_products[:90]

# %%
response = llm.invoke('can you add an appropriate category for each product title in unique products in a format given as - men or women, if men or women then- if  Topwear, western wear, Indian and fusion wear, Bottomwear,Sleepwear,sports and active wear. Return as a dataframe - column 1 - product , column 2- (Gender) men/women, column 3 - appropriate category, fashion accessories for :'+','.join(unique_products[1:30]))
response = response.split('\n')
# Out:
# {"function":"launch_slot_with_data","level":"INFO","line":830,"msg":"slot is processing task","slot_id":0,"task_id":25,"tid":"133744299075328","timestamp":1711627153}
# {"function":"update_slots","ga_i":0,"level":"INFO","line":1821,"msg":"slot progression","n_past":15,"n_past_se":0,"n_prompt_tokens_processed":586,"slot_id":0,"task_id":25,"tid":"133744299075328","timestamp":1711627153}
# {"function":"update_slots","level":"INFO","line":1848,"msg":"kv cache rm [p0, end)","p0":15,"slot_id":0,"task_id":25,"tid":"133744299075328","timestamp":1711627153}
# {"function":"print_timings","level":"INFO","line":257,"msg":"prompt eval time     =    1251.08 ms /   586 tokens (    2.13 ms per token,   468.39 tokens per second)","n_prompt_tokens_processed":586,"n_tokens_second":468.3945576708801,"slot_id":0,"t_prompt_processing":1251.082,"t_token":2.1349522184300342,"task_id":25,"tid":"133744299075328","timestamp":1711627171}
# ...

# %% [markdown]
# can you add an appropriate category for each product title in unique products in a format given as - column1 men or women, if men or women then- column 2,3,4,5,6,7,8- Topwear, western wear, Indian and fusion wear, Bottomwear,Sleepwear,sports and active wear, fashion accessories.

# %%
len(response)
# Out:
# 10

# %%
# Get index list
#https://stackoverflow.com/questions/47518609/for-loop-range-and-interval-how-to-include-last-step
def hop(start, stop, step):
    for i in range(start, stop, step):
        yield i
    yield stop

index_list = list(hop(0, len(unique_products), 30))
index_list
# Out:
# [0, 30, 60, 90]

# %%
def categorize_transactions(transaction_names, llm):
    response = llm.invoke('can you add an appropriate category for each product title in unique products in a format given as - men or women, if men or women then- if  Topwear, western wear, Indian and fusion wear, Bottomwear,Sleepwear,sports and active wear. Return as a dataframe - column 1 - product , column 2- (Gender) men/women, column 3 - appropriate category, fashion accessories for :'+','.join(unique_products))
    response = response.split('\n')

    print(response)

    # Put in dataframe
    categories_df = pd.DataFrame({'Transaction vs category': response})
    categories_df[['Transaction', 'Category']] = categories_df['Transaction vs category'].str.split(' - ', expand=True)
    
    return categories_df

# %%
# Intialise the categories_df_all dataframe
categories_df_all = pd.DataFrame()

# Loop through the index_list
for i in range(0, len(index_list)-1):
    transaction_names = unique_products[index_list[i]:index_list[i+1]]
    transaction_names = ','.join(transaction_names)

    categories_df = categorize_transactions(transaction_names, llm)
    categories_df_all = pd.concat([categories_df_all, categories_df], ignore_index=True)
# Out:
# time=2024-03-28T12:28:41.031Z level=INFO source=cpu_common.go:11 msg="CPU has AVX2"
# time=2024-03-28T12:28:41.031Z level=INFO source=gpu.go:119 msg="CUDA Compute Capability detected: 7.5"
# time=2024-03-28T12:28:41.031Z level=INFO source=cpu_common.go:11 msg="CPU has AVX2"
# time=2024-03-28T12:28:41.031Z level=INFO source=gpu.go:119 msg="CUDA Compute Capability detected: 7.5"
# time=2024-03-28T12:28:41.031Z level=INFO source=cpu_common.go:11 msg="CPU has AVX2"
# time=2024-03-28T12:28:41.031Z level=INFO source=dyn_ext_server.go:90 msg="Loading Dynamic llm server: /tmp/ollama676805227/runners/cuda_v11/libext_server.so"
# time=2024-03-28T12:28:41.032Z level=INFO source=dyn_ext_server.go:150 msg="Initializing llama server"
# llama_model_loader: loaded meta data with 23 key-value pairs and 291 tensors from /root/.ollama/models/blobs/sha256:8934d96d3f08982e95922b2b7a2c626a1fe873d7c3b06e8e56d7bc0a1fef9246 (version GGUF V3 (latest))
# ...

# %%
categories_df_all
# Out:
#                               Transaction vs category  \
# 0
# 1     Here is the data frame for the products listed:
# 2
# 3                     | Product | Gender | Category |
# 4                                 | --- | --- | --- |
# ..                                                ...
# 75  | 612 league Boys Red & Beige Solid Kurta with...
# 76  | Jompers Men Red & Beige Self Design Kurta wi...
# 77  | TREEMODA Men Pink & White Solid Linen Kurta ...
# 78
# 79  Note: The gender column specifies the gender o...
#
#                                           Transaction Category
# 0                                                         None
# 1     Here is the data frame for the products listed:     None
# 2                                                         None
# 3                     | Product | Gender | Category |     None
# 4                                 | --- | --- | --- |     None
# ..                                                ...      ...
# ...
